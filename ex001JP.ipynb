# %% [markdown]
# <a href="https://colab.research.google.com/github/marcelacdarocha/EstudosPY/blob/main/ex001JP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
imagem =  cv2.imread('/content/drive/MyDrive/SIRROS/ltq2.jpg')

# %%
imagem.shape
# Out:
# (590, 960, 3)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=960x590 at 0x7FBB9A9FA5D0>

# %%
imagem_cinza = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)
cv2_imshow(imagem_cinza)
# Out:
# <PIL.Image.Image image mode=L size=960x590 at 0x7FBB9A1351D0>

# %%
def BrightnessContrast(brightness=0): 
  
    
    
    brightness = cv2.getTrackbarPos('Brightness', 
                                    'imagem_cinza') 
      
    contrast = cv2.getTrackbarPos('Contrast', 
                                  'imagem_cinza') 
      
    effect = controller(img, 
                        brightness, 
                        contrast) 
  
    
    
    cv2.imshow('Effect', effect)

# %%
cv2_imshow(imagem_cinza)
# Out:
# <PIL.Image.Image image mode=L size=960x590 at 0x7FBB97E5B090>
